# %% [markdown]
# Nesse exercicio vamos analisar o conjunto de dados Bithweight. **URL do conjunto de dados:
# https://www.sheffield.ac.uk/polopoly_fs/1.937185!/file/Birthweight_reduced_kg_R.csv**
#
# Fonte: Mathematics and Statistics Help (MASH), Universidade de Sheffield, Reino Unido.

# %% [markdown]
# ### Descrição dos atributos:
#
# **ID**: número do bebê
#
# **Length**: comprimento do bebê (cm)
#
# **Birthweight**: peso do bebê (kg)
#
# **Headcirc**: circunferência da cabeça
#
# **Gestation**: gestação (semanas)
#
# **smoker**: mãe fumante (1 = sim, 0 = não)
#
# **mage**: idade da mãe
#
# **mnocig**: número de cigarros por dia da mãe
#
# **mheight**: altura da mãe (cm)
#
# **mppwt**: peso pré-gravidez da mãe (kg)
#
# **fage**: idade do pai
#
# **fedyrs**: anos de escolaridade do pai
#
# **fnocig**: número de cigarros por dia do pai
#
# **fheight**: altura do pai (cm)
#
# **lowbwt**: baixo peso do bebê (0 = não, 1 = sim)
#
# **mage35**: mãe acima dos 35 anos (0 = não, 1 = sim)

# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt 
sb.set(rc={'figure.figsize':(15,8)})

# %%
df=pd.read_csv('https://www.sheffield.ac.uk/polopoly_fs/1.937185!/file/Birthweight_reduced_kg_R.csv')

# %%
df.head(10)
# Out:
#      ID  Length  Birthweight  Headcirc  Gestation  smoker  mage  mnocig  \
# 0  1360      56         4.55        34         44       0    20       0
# 1  1016      53         4.32        36         40       0    19       0
# 2   462      58         4.10        39         41       0    35       0
# 3  1187      53         4.07        38         44       0    20       0
# 4   553      54         3.94        37         42       0    24       0
# 5  1636      51         3.93        38         38       0    29       0
# 6   820      52         3.77        34         40       0    24       0
# 7  1191      53         3.65        33         42       0    21       0
# 8  1081      54         3.63        38         38       0    18       0
# 9   822      50         3.42        35         38       0    20       0
#
#    mheight  mppwt  fage  fedyrs  fnocig  fheight  lowbwt  mage35
# 0      162     57    23      10      35      179       0       0
# ...

# %%
#Analisando o peso de nascimento dos bêbes 
sb.displot(df['Birthweight']);

# %%
df['Birthweight'].describe()
# Out:
# count    42.000000
# mean      3.312857
# std       0.603895
# min       1.920000
# 25%       2.940000
# 50%       3.295000
# 75%       3.647500
# max       4.570000
# Name: Birthweight, dtype: float64

# %%
#Analisando o tamanho de nascimento dos bêbes
sb.displot(df['Length']);

# %%
df['Length'].describe()
# Out:
# count    42.000000
# mean     51.333333
# std       2.935624
# min      43.000000
# 25%      50.000000
# 50%      52.000000
# 75%      53.000000
# max      58.000000
# Name: Length, dtype: float64

# %%
#Analisando as variaveis categoricas

# %%
sb.displot(df['smoker']);

# %%
sb.displot(df['lowbwt']);

# %%
#verificando correlação entre os atributos 
correlacao = df.corr()

# %%
#criando matriz de correlação 
plot = sb.heatmap(correlacao, annot = True, fmt=".1f", linewidths=.6)
plot;

# %% [markdown]
# A matriz mostra correlação negativa entre o peso de nascimento e a duração da gestação.

# %%
#Visualizando a correlação
sb.scatterplot(x=df['Birthweight'],y=df['Gestation'], hue=df['smoker'])
plt.show()

# %%
sb.scatterplot(x=df['Birthweight'],y=df['Gestation'], hue=df['mage35'])
plt.show()

# %%
maes_fumantes = (df[df['smoker']==1])
sb.scatterplot(x=df['Birthweight'],y=maes_fumantes['mnocig'])
plt.show()

# %%
maes_fumantes = (df[df['smoker']==1])
sb.scatterplot(x=df['Birthweight'],y=maes_fumantes['fnocig'])
plt.show()

# %%
sb.scatterplot(x=df['Birthweight'],y=df['mppwt'], hue=df['mage35'])
plt.show()

# %%
sb.scatterplot(x=df['Birthweight'],y=df['mppwt'], hue=df['smoker'])
plt.show()
